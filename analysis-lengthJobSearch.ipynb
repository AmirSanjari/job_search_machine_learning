# %%
from loadData import loadData
from initAnalysis import initAnalysis
import pandas as pd 
from matplotlib import pyplot as plt

# %%
dataFrame = loadData()
targetPlaced, dataPlaced, targetNotPlaced, dataNotPlaced = initAnalysis(dataFrame)


lengthJobSearchPlaced = dataPlaced["length_of_job_search"]
lengthJobSearchNotPlaced = dataNotPlaced["length_of_job_search"]


lengthJobSearchPlaced.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.ylabel('')
plt.title('Placed - Length Of Job Search Status')
plt.show()


lengthJobSearchNotPlaced.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title('Not Placed -  Length Of Job Search Status')
plt.ylabel('')
plt.show()

# lengthJobSearchPlacedDataFrame = pd.DataFrame({
#     'Placed': lengthJobSearchPlaced,
# }).dropna()

# lengthJobSearchPlacedDataFrame.replace("Less than one month",15,inplace=True)
# lengthJobSearchPlacedDataFrame.replace("1-2 months",45,inplace=True)
# lengthJobSearchPlacedDataFrame.replace("3-5 months",120,inplace=True)
# lengthJobSearchPlacedDataFrame.replace("6 months to a year",270,inplace=True)
# lengthJobSearchPlacedDataFrame.replace("Over a year",540,inplace=True)




# lengthJobSearchNotPlacedDataFrame = pd.DataFrame({
#     'Not Placed': lengthJobSearchlNotPlaced
# }).dropna()

# lengthJobSearchNotPlacedDataFrame.replace("Less than one month",15,inplace=True)
# lengthJobSearchNotPlacedDataFrame.replace("1-2 months",45,inplace=True)
# lengthJobSearchNotPlacedDataFrame.replace("3-5 months",120,inplace=True)
# lengthJobSearchNotPlacedDataFrame.replace("6 months to a year",270,inplace=True)
# lengthJobSearchNotPlacedDataFrame.replace("Over a year",540,inplace=True)
